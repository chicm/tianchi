# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os, cv2, gc
from matplotlib import pyplot as plt
from tqdm import tqdm

# %matplotlib inline

# %%
train_data = '/home/chicm/ml/kgdata/tianchi/tutorial_out/masks/train_final_images.npy'
mask_data = '/home/chicm/ml/kgdata/tianchi/tutorial_out/masks/train_final_masks.npy'

val_data = '/home/chicm/ml/kgdata/tianchi/tutorial_out/masks/val_final_images.npy'
val_mask = '/home/chicm/ml/kgdata/tianchi/tutorial_out/masks/val_final_masks.npy'

# %%
imgs_train = np.load(train_data).astype(np.float32)
masks_train = np.load(mask_data).astype(np.float32)

imgs_val = np.load(val_data).astype(np.float32)
masks_val = np.load(val_mask).astype(np.float32)

# %%
minvalue = np.min(imgs_train)
maxvalue = np.max(imgs_train)
#imgs_train -= minvalue
#imgs_train /= (maxvalue-minvalue)
print(np.max(imgs_train))
print(np.max(masks_train))
print(np.min(imgs_train))
print(np.min(masks_train))
# Out:
# 0.915437
# 0.00392157
# -0.821098
# 0.0

# %%
#minvalue = np.min(imgs_train)
#maxvalue = np.max(imgs_train)
#imgs_train -= minvalue
#imgs_train /= (maxvalue-minvalue)
print(np.max(imgs_val))
print(np.max(masks_val))
print(np.min(imgs_val))
print(np.min(masks_val))
# Out:
# 0.804587
# 0.00392157
# -0.557979
# 0.0

# %%
mask1 = np.load('/home/chicm/ml/kgdata/tianchi/tutorial_out/masks/train/masks_LKDS-00996_0707.npy')
print(np.max(mask1))
plt.imshow(mask1[0])
# Out:
# 1

# %%
print(imgs_train.shape)
print(masks_train.shape)
# Out:
# (2922, 1, 512, 512)
# (2922, 1, 512, 512)

# %%
masks_train *= 255
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean  # images should already be standardized, but just in case
imgs_train /= std

print(np.max(imgs_train))
print(np.max(masks_train))
print(np.min(imgs_train))
print(np.min(masks_train))
print(np.mean(imgs_train))
print(np.mean(masks_train))

print(np.std(imgs_train))
print(np.std(masks_train))
# Out:
# 5.65898
# 255.0
# -5.07427
# 0.0
# 1.67676e-08
# 1.69195
# 0.999997
# 20.4886

# %%
plt.figure(figsize=(32,32))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_train[i+200][0])
    #plt.imshow(masks_train[i+20][0])
    #plt.title(y_train[i+20])

# %%
plt.figure(figsize=(32,32))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(masks_train[i+200][0])

# %%
plt.figure(figsize=(32,32))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_val[i+200][0])
    #plt.imshow(masks_train[i+20][0])
    #plt.title(y_train[i+20])

# %%
plt.figure(figsize=(32,32))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(masks_val[i+200][0])
